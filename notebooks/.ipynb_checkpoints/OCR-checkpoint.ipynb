# %%
from ocr import OCR
from PIL import Image
import cv2
import os
import keras_ocr
import matplotlib.pyplot as plt
# Out:
# 2022-11-21 16:45:43.446222: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-21 16:45:44.100843: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...

# %%
# Opens a image in RGB mode
# im = Image.open(r"og_pictures/P001, L eye, V2, 6.0 - Density DP.png")
im = Image.open(r"og_pictures/1.png")

# Size of the image in pixels (size of original image)
# (This is not mandatory)
width, height = im.size
print(width,height)
# Setting the points for cropped image
table={
    'l' : 1530,
    't' : 150,
    'r' : 1820,
    'b' : 650
    }

cropped = im.crop((table['l'], table['t'], table['r'], table['b']))
display(cropped)

# Shows the image in image viewer
# Out:
# 1920 1080
# <PIL.Image.Image image mode=RGB size=290x500>

# %%
cropped.save('evaluate/cropped.png')

# %%
ocr=OCR(image_folder="evaluate/")

if __name__ == "__main__":
#     ocr.keras_ocr_works()  #THIS WORKS TERRIBLY
    ocr.easyocr_model_works()  
#     ocr.pytesseract_model_works()
# Out:
# IMAGES: evaluate/ cropped.png
# IMAGES: evaluate/ cropped_2.png
# Looking for /home/carlo/.keras-ocr/craft_mlt_25k.h5
# 2022-11-21 16:45:49.417999: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/carlo/anaconda3/envs/eyes/lib/python3.10/site-packages/cv2/../../lib64:
# 2022-11-21 16:45:49.418042: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-11-21 16:45:49.418061: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (C-A0051900): /proc/driver/nvidia/version does not exist
# ...

# %%
img = cv2.imread(os.path.join('evaluate/cropped.png'))
gray = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
images=[gray]

# %%
def keras_ocr_works(images,visualization=True):
        print('HEREEEEEEEEE')
        images = [keras_ocr.tools.read(img) for img in images]
        pipeline = keras_ocr.pipeline.Pipeline()
        prediction_groups = pipeline.recognize(images) # prediction
        print(prediction_groups)
        if visualization:
            fig, axs = plt.subplots(nrows=len(images), figsize=(20, 20))
            for ax, image, predictions in zip(axs, images, prediction_groups):
                keras_ocr.tools.drawAnnotations(image=image, predictions=predictions, ax=ax,)
result=keras_ocr_works(images,False)
# Out:
# HEREEEEEEEEE
# Looking for /home/carlo/.keras-ocr/craft_mlt_25k.h5
# Looking for /home/carlo/.keras-ocr/crnn_kurapan.h5
# ...
# 3/3 [==============================] - 4s 966ms/step
# [[('58', array([[22., 10.],
#        [43., 10.],
#        [43., 24.],
#        [22., 24.]], dtype=float32)), ('whole', array([[ 79.999985,   9.999999],
#        [125.999985,  10.      ],
#        [125.999985,  23.999996],
#        [ 79.999985,  23.999996]], dtype=float32)), ('image', array([[127.20029 ,   9.463181],
#        [173.69995 ,  13.134205],
#        [172.54785 ,  27.727459],
#        [126.04819 ,  24.056435]], dtype=float32)), ('307', array([[244.,  10.],
#        [272.,  10.],
#        [272.,  24.],
#        [244.,  24.]], dtype=float32)), ('8', array([[42., 11.],
#        [52., 11.],
#        [52., 23.],
#        [42., 23.]], dtype=float32)), ('541', array([[23., 31.],
#        [52., 31.],
#        [52., 45.],
#        [23., 45.]], dtype=float32)), ('superiorhemi', array([[ 79.,  31.],
# ...

# %%
# Out:
# array([[[100, 100, 100],
#         [255, 255, 255],
#         [240, 240, 240],
#         ...,
#         [240, 240, 240],
#         [240, 240, 240],
#         [240, 240, 240]],
#
#        [[100, 100, 100],
#         [255, 255, 255],
#         [240, 240, 240],
#         ...,
#         [240, 240, 240],
#         [240, 240, 240],
#         [240, 240, 240]],
#
#        [[100, 100, 100],
#         [255, 255, 255],
#         [240, 240, 240],
#         ...,
#         [240, 240, 240],
#         [240, 240, 240],
#         [240, 240, 240]],
#
#        ...,
#
#        [[  2,   0,   2],
#         [  4,   2,   4],
#         [  2,   0,   2],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[  0,   0,   0],
#         [  2,   0,   2],
#         [  4,   1,   4],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[187, 187, 187],
#         [  0,   0,   0],
#         [  0,   0,   0],
# ...
